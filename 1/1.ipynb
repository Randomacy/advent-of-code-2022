# %%
with open('input.txt') as f:
    lines = f.readlines()

# %%
elves = []
new_elf = 0

for i in lines:
    if i != '\n':
        new_elf += int(i.strip())
    else:
        elves.append(new_elf)
        new_elf = 0

# %%
elves
# Out:
# [67852,
#  62262,
#  45402,
#  53612,
#  53957,
#  40312,
#  37005,
#  44882,
#  39530,
#  54569,
#  59762,
#  4148,
#  57926,
#  47686,
#  61872,
#  49497,
#  18803,
#  49082,
#  37241,
#  56764,
#  48416,
#  53270,
#  52433,
#  40129,
#  34309,
#  55945,
#  48172,
#  68164,
#  49054,
#  40909,
#  7781,
#  56491,
#  44652,
#  21711,
#  52036,
#  46745,
#  63465,
#  48858,
#  16430,
#  53447,
#  53661,
#  56481,
#  52268,
#  48663,
#  1175,
#  44492,
#  52428,
#  51425,
#  56825,
#  53656,
#  37017,
#  58686,
#  44031,
#  38549,
#  52802,
#  30443,
#  61005,
#  55384,
#  56490,
#  39028,
#  47723,
#  47672,
#  11627,
#  46489,
#  57620,
#  53765,
#  26968,
#  41240,
#  56955,
#  35462,
#  41708,
#  40480,
#  52203,
#  38593,
#  46644,
#  54446,
#  49616,
#  59211,
#  38703,
#  69894,
#  17416,
#  40643,
#  58134,
#  53675,
#  55490,
#  43421,
#  65598,
#  49757,
#  51242,
#  53281,
#  48828,
#  51181,
#  57674,
#  57392,
#  58144,
#  40182,
#  48153,
#  54355,
#  43503,
#  49599,
# ...
